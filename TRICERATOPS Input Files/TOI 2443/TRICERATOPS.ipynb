# 5        NaN  3992.00   1.055640        64.867      330.157  9.265862e-06
# 6        NaN      NaN   0.771227        69.797      348.539  4.557670e-06
# 7        NaN  4099.00   0.507044        88.414      285.500  7.307970e-07
# 8   0.697812  5111.00   1.395140       101.360      267.837  3.834747e-06
# 9        NaN  4228.00   0.406682       104.160       66.881  1.069601e-06
# 10       NaN      NaN        NaN       115.734      145.426  1.002366e-08
# 11       NaN      NaN  -0.590087       143.434       21.879  5.740337e-12
# 12  1.082490  4847.29   1.300830       150.090      126.943  9.616663e-12
# 13  0.324468  3418.00   3.847950       152.045      297.447  9.005290e-14
# 14       NaN      NaN        NaN       155.076      170.400  3.064249e-15
# 15       NaN  3391.00   2.773350       157.485      242.312  1.639074e-15
# 16       NaN  3346.00   3.551160       161.715      299.894  1.699386e-16
# 17  0.514372  3714.00        NaN       177.335      173.829  8.573933e-17
# 18       NaN      NaN  -0.194071       183.617      115.416  2.354765e-18
# 19       NaN      NaN   1.475870       183.894      293.925  3.495129e-21
# 20       NaN      NaN        NaN       190.943       45.157  3.754903e-19
# 21       NaN  5760.00   0.196120       192.218      302.347  1.217655e-22
# 22       NaN  4038.00   0.876678       194.167       62.609  9.920987e-20
# 23       NaN  5056.00   0.831009       195.875      175.135  4.558592e-23
# 24  0.664662  4512.00   0.682656       196.256      190.110  1.840977e-21
#
#       tdepth
# 0   0.001222
# 1   0.000000
# 2   0.596876
# 3   0.000000
# 4   0.114294
# 5   0.000000
# 6   0.000000
# 7   0.000000
# 8   0.000000
# 9   0.000000
# 10  0.000000
# 11  0.000000
# 12  0.000000
# 13  0.000000
# 14  0.000000
# 15  0.000000
# 16  0.000000
# 17  0.000000
# 18  0.000000
# 19  0.000000
# 20  0.000000
# 21  0.000000
# 22  0.000000
# 23  0.000000
# 24  0.000000

# %% [markdown]
# # Ploting CC File

# %%
cc = pd.read_csv(contrastcurve_file, header=None)
sep, dmag = cc[0].values, cc[1].values

plt.plot(sep, dmag, 'k-');
plt.ylim(10,0);
plt.ylabel("$\\Delta K_s$", fontsize=20);
plt.xlabel("separation ('')", fontsize=20);

# %% [markdown]
# # Calculating FPP & NFPP

# %%
# %%time

for i in range(1):
    
    lc = pd.read_csv("TOI_2443_31.csv", header=None)
    contrastcurve_file = "Gemini_8m_g.csv"

    band = 'Vis'
    
    # read in the light curve
    time, flux, flux_err = lc[0].values, lc[1].values, lc[2].values
    P_orb = period

    #lc_binsize = (time.max()-time.min())/100
    lc = TessLightCurve(time=time, flux=flux, flux_err=flux_err)#.bin(time_bin_size=lc_binsize)

    target.calc_probs(time = lc.time.value, 
                        flux_0 = lc.flux.value, 
                        flux_err_0 = np.mean(lc.flux_err.value), 
                        P_orb = P_orb,
                        contrast_curve_file = contrastcurve_file,
                        filt = band,
                        exptime = 0.0013888888888889)
    
    df_results = target.probs
    print("FPP = ", target.FPP)
    print("NFPP = ", target.NFPP)
# Out:
# Calculating TP scenario probabilitiey for 318753380.
# Calculating EB and EBx2P scenario probabilities for 318753380.
# Calculating PTP scenario probability for 318753380.
# Calculating PEB and PEBx2P scenario probabilities for 318753380.
# Calculating STP scenario probability for 318753380.
# Calculating SEB and SEBx2P scenario probabilities for 318753380.
# Calculating DTP scenario probability for 318753380.
# Calculating DEB and DEBx2P scenario probabilities for 318753380.
# Calculating BTP scenario probability for 318753380.
# Calculating BEB and BEBx2P scenario probabilities for 318753380.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 318753384.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 318753383.
# FPP =  0.0
# NFPP =  1.9127520271793717e-19
# Calculating TP scenario probabilitiey for 318753380.
# Calculating EB and EBx2P scenario probabilities for 318753380.
# Calculating PTP scenario probability for 318753380.
# Calculating PEB and PEBx2P scenario probabilities for 318753380.
# Calculating STP scenario probability for 318753380.
# Calculating SEB and SEBx2P scenario probabilities for 318753380.
# Calculating DTP scenario probability for 318753380.
# Calculating DEB and DEBx2P scenario probabilities for 318753380.
# Calculating BTP scenario probability for 318753380.
# Calculating BEB and BEBx2P scenario probabilities for 318753380.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 318753384.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 318753383.
# FPP =  0.0
# NFPP =  8.881721119445782e-20
# Calculating TP scenario probabilitiey for 318753380.
# Calculating EB and EBx2P scenario probabilities for 318753380.
# Calculating PTP scenario probability for 318753380.
# Calculating PEB and PEBx2P scenario probabilities for 318753380.
# Calculating STP scenario probability for 318753380.
# Calculating SEB and SEBx2P scenario probabilities for 318753380.
# Calculating DTP scenario probability for 318753380.
# Calculating DEB and DEBx2P scenario probabilities for 318753380.
# Calculating BTP scenario probability for 318753380.
# Calculating BEB and BEBx2P scenario probabilities for 318753380.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 318753384.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 318753383.
# FPP =  0.0
# NFPP =  2.3136194379886132e-19
# Calculating TP scenario probabilitiey for 318753380.
# Calculating EB and EBx2P scenario probabilities for 318753380.
# Calculating PTP scenario probability for 318753380.
# Calculating PEB and PEBx2P scenario probabilities for 318753380.
# Calculating STP scenario probability for 318753380.
# Calculating SEB and SEBx2P scenario probabilities for 318753380.
# Calculating DTP scenario probability for 318753380.
# Calculating DEB and DEBx2P scenario probabilities for 318753380.
# Calculating BTP scenario probability for 318753380.
# Calculating BEB and BEBx2P scenario probabilities for 318753380.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 318753384.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 318753383.
# FPP =  1.1102230246251565e-16
# NFPP =  1.2347898888412088e-19
# Calculating TP scenario probabilitiey for 318753380.
# Calculating EB and EBx2P scenario probabilities for 318753380.
# Calculating PTP scenario probability for 318753380.
# Calculating PEB and PEBx2P scenario probabilities for 318753380.
# Calculating STP scenario probability for 318753380.
# Calculating SEB and SEBx2P scenario probabilities for 318753380.
# Calculating DTP scenario probability for 318753380.
# Calculating DEB and DEBx2P scenario probabilities for 318753380.
# Calculating BTP scenario probability for 318753380.
# Calculating BEB and BEBx2P scenario probabilities for 318753380.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 318753384.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 318753383.
# FPP =  0.0
# NFPP =  2.196043460168508e-19
# Calculating TP scenario probabilitiey for 318753380.
# Calculating EB and EBx2P scenario probabilities for 318753380.
# Calculating PTP scenario probability for 318753380.
# Calculating PEB and PEBx2P scenario probabilities for 318753380.
# Calculating STP scenario probability for 318753380.
# Calculating SEB and SEBx2P scenario probabilities for 318753380.
# Calculating DTP scenario probability for 318753380.
# Calculating DEB and DEBx2P scenario probabilities for 318753380.
# Calculating BTP scenario probability for 318753380.
# Calculating BEB and BEBx2P scenario probabilities for 318753380.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 318753384.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 318753383.
# FPP =  0.0
# NFPP =  1.3120997868776336e-19
# Wall time: 1h 27min 26s

# %%
df_results = target.probs
print("FPP = ", target.FPP)
print("NFPP = ", target.NFPP)
df_results
# Out:
# FPP =  0.0
# NFPP =  1.3120997868776336e-19
#            ID scenario       M_s       R_s      P_orb        inc         b  \
# 0   318753380       TP  0.660000  0.732115  15.669213  89.922430  0.048675
# 1   318753380       EB  0.660000  0.732115  15.669213  84.432598  1.380386
# 2   318753380    EBx2P  0.660000  0.732115  31.338427  89.013004  0.282020
# 3   318753380      PTP  0.660000  0.732115  15.669213  89.708396  0.188456
# 4   318753380      PEB  0.660000  0.732115  15.669213  85.923460  1.513531
# 5   318753380   PEBx2P  0.660000  0.732115  31.338427  89.022725  0.449090
# 6   318753380      STP  0.588307  0.590314  15.669213  89.754551  0.143799
# 7   318753380      SEB  0.101148  0.121644  15.669213  89.801422  0.194749
# 8   318753380   SEBx2P  0.252726  0.277067  31.338427  89.394945  0.316992
# 9   318753380      DTP  0.660000  0.732115  15.669213  89.875251  0.044346
# 10  318753380      DEB  0.660000  0.732115  15.669213  85.949166  1.332724
# 11  318753380   DEBx2P  0.660000  0.732115  31.338427  89.060911  0.165506
# 12  318753380      BTP  1.068000  1.167668  15.669213  88.701637  0.363021
# 13  318753380      BEB  0.788000  0.741817  15.669213  89.757512  0.125209
# 14  318753380   BEBx2P  1.077000  2.056561  31.338427  88.432670  1.015768
# 15  318753384      NTP  1.170000  1.109410  15.669213  89.380960  0.266983
# 16  318753384      NEB  1.170000  1.109410  15.669213  89.932214  0.032366
# 17  318753384   NEBx2P  1.170000  1.109410  31.338427  89.954060  0.038993
# 18  318753383      NTP  0.709000  0.925974  15.669213  89.527900  0.216134
# 19  318753383      NEB  0.709000  0.925974  15.669213  89.927415  0.035021
# 20  318753383   NEBx2P  0.709000  0.925974  31.338427  88.834885  1.144601
#
#          ecc           w        R_p      M_EB      R_EB           prob
# 0   0.235819  228.580891   2.664465  0.000000  0.000000   6.510628e-01
# 1   0.647678   67.006733   0.000000  0.624201  0.600616   0.000000e+00
# 2   0.879219  188.999958   0.000000  0.630873  0.650002   3.534046e-97
# 3   0.286798  231.131771   2.725372  0.000000  0.000000   2.538345e-03
# 4   0.479814   42.819193   0.000000  0.398157  0.400631   0.000000e+00
# 5   0.786625  186.946502   0.000000  0.648797  0.671971   2.529822e-78
# 6   0.350959  183.749264   3.780886  0.000000  0.000000   1.617398e-70
# 7   0.757422  192.808267   0.000000  0.028629  0.100000  5.414350e-135
# 8   0.823025  159.252758   0.000000  0.251541  0.276030   4.133542e-93
# 9   0.377681  122.324547   2.679755  0.000000  0.000000   3.463989e-01
# 10  0.523012   75.178811   0.000000  0.621965  0.600666   0.000000e+00
# 11  0.907311  174.217551   0.000000  0.639069  0.660085   9.854881e-50
# 12  0.319366   66.544482  14.626001  0.000000  0.000000   2.592935e-48
# 13  0.292000  152.751873   0.000000  0.311744  0.327837   2.181600e-65
# 14  0.805907  290.828189   0.000000  1.046681  1.146788   1.291926e-33
# 15  0.143733  183.221931  19.962266  0.000000  0.000000   0.000000e+00
# 16  0.120288  118.944531   0.000000  0.985069  1.057418   1.606000e-64
# 17  0.129267    1.736799   0.000000  1.113499  1.109410   1.249662e-89
# 18  0.034003  277.310068  19.986267  0.000000  0.000000   0.000000e+00
# 19  0.051025  148.879526   0.000000  0.289825  0.309174   1.312100e-19
# 20  0.129177  290.823109   0.000000  0.674311  0.702301   3.213233e-35

# %%
target.plot_fits(time=time, flux_0=flux, flux_err_0=np.mean(flux_err))

# %%
# Filter: BrGamma
FPP_BrGamma = [1.8220225328491324e-10, 0, 0, 0,
               0, 0, 1.1102230246251565e-16, 0, 
               1.9957897556821536e-09, 1.1102230246251565e-16, 0, 0, 0, 0, 0, 0]
NFPP_BrGamma = [2.242038958758589e-19, 1.4142840494685804e-19, 3.350713314599134e-19, 1.4812192454574752e-19,
                1.3497943697450751e-19, 1.3887652078641487e-19, 1.7982996527046176e-19, 2.2296754539411387e-19,
                1.315440928124915e-19, 1.9127520271793717e-19, 8.881721119445782e-20, 2.3136194379886132e-19,
                2.3136194379886132e-19, 1.2347898888412088e-19, 2.196043460168508e-19, 1.3120997868776336e-19]

print("Filter: BrGamma")
print("   FPP  = ",np.mean(FPP_BrGamma),"+/-",np.std(FPP_BrGamma))
print("   NFPP = ",np.mean(NFPP_BrGamma),"+/-",np.std(NFPP_BrGamma))
# Out:
# Filter: BrGamma
#    FPP  =  1.3612451443822948e-10 +/- 4.821758156452928e-10
#    NFPP =  1.7963329582282625e-19 +/- 5.983114813829883e-20
