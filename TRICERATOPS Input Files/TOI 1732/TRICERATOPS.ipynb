# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import time
from lightkurve import TessLightCurve
import matplotlib.pyplot as plt
# %matplotlib inline

import triceratops.triceratops as tr

# %% [markdown]
# # User Inputs
#
# * **ID** = TIC ID of selected target
# * **sectors** = Observational sector of TESS
#
#
# * **period** = Orbital Period
# * **tdepth** = Transit Depth
#
#
# * **lc** = Light curve file
# * **contrastcurve_file** = Contrast curve file
#
#
# * **band** = Band of filter through which CC file was created. (TESS, Vis, J, H, K)
# From table below we can identify which band to choose.
#
# |   Wavelength   | Central Wavelength | Filter |
# |:--------------:|:------------------:|:------:|
# |  600 - 1000 nm | 786.5 nm           |  TESS  |
# |   400 - 800 nm | 550 nm             |   Vis  |
# | 1000 - 1500 nm | 1250 nm            |   J    |
# | 1400 - 2000 nm | 1650 nm            |   H    |
# | 1800 - 2600 nm | 2200 nm            |   K    |
#
# * We usually encounter with following wavelengths,
#  - **562 nm** : Vis filter
#  - **832 nm** : TESS filter
#  - **Br-Gamma** (2172 - 2202 nm) : K filter
#  - **Jcont** (1190 - 1230 nm) : J filter

# %% [markdown]
# # I/P

# %% [markdown]
# * *Use these values for input*
#
#   - **Sector :**
# Period =
# tdepth = **2
#
#   - **Sector :**
# Period =
# tdepth = **2

# %%
ID = 470987100
sectors = np.array([20])

period = 4.1192418194
tdepth = 0.0388925079**2

lc = pd.read_csv("TOI_1732_20.csv", header=None)
contrastcurve_file = "Palomar_5m_K.csv"

band = 'K'

# %% [markdown]
# # Downloading & Visualizing Data

# %%
target = tr.target(ID=ID, sectors=sectors)

# %%
ap = np.array([[2025, 149], [2024, 150], [2025, 150], [2026, 150], 
               [2024, 151], [2025, 151], [2026, 151], [2024, 152], 
               [2025, 152], [2026, 152]])

target.plot_field(sector = sectors[0], ap_pixels = ap)
 
target.stars
# Out:
#            ID     Tmag    Jmag    Hmag    Kmag          ra        dec  \
# 0   470987100  11.3266  10.130   9.458   9.255  111.801499  53.045087
# 1   470987101  15.6780  14.861  14.372  14.277  111.806043  53.047085
# 2   742761070  19.5419     NaN     NaN     NaN  111.814226  53.042674
# 3   470987102  18.6348  16.706  15.837  15.919  111.819780  53.047389
# 4   742761069  20.4246     NaN     NaN     NaN  111.793183  53.031054
# ..        ...      ...     ...     ...     ...         ...        ...
# 61  742761089  18.6908     NaN     NaN     NaN  111.881429  53.072788
# 62  742761081  20.3890     NaN     NaN     NaN  111.893627  53.048124
# 63  742820951  19.9516     NaN     NaN     NaN  111.713286  53.028038
# 64  470987086  18.3634  16.536  15.870  15.752  111.749313  52.998533
# 65  742761083  20.2175     NaN     NaN     NaN  111.890331  53.062599
#
#         mass       rad    Teff        plx  sep (arcsec)  PA (E of N)
# 0   0.613891  0.632571  3876.0  13.347400         0.000        0.000
# 1   0.870000  0.677439  5135.0   0.986836        12.184       53.810
# 2        NaN       NaN     NaN   0.481227        28.883      107.500
# 3   0.470000  0.425494  3517.0   0.925601        40.422       78.159
# 4        NaN       NaN     NaN  -1.390740        53.630      199.617
# ..       ...       ...     ...        ...           ...          ...
# 61       NaN       NaN  3711.0   0.880022       199.628       59.998
# 62       NaN       NaN     NaN   0.735659       199.682       86.824
# 63       NaN       NaN     NaN        NaN       200.577      252.217
# 64       NaN       NaN  3157.0   2.234230       202.134      214.012
# 65       NaN       NaN     NaN   0.787066       202.291       71.806
#
# [66 rows x 13 columns]

# %% [markdown]
# # Check Nearby Region

# %%
apertures = np.array([ap])
target.calc_depths(tdepth = tdepth, all_ap_pixels = apertures)

target.stars
# Out:
#            ID     Tmag    Jmag    Hmag    Kmag          ra        dec  \
# 0   470987100  11.3266  10.130   9.458   9.255  111.801499  53.045087
# 1   470987101  15.6780  14.861  14.372  14.277  111.806043  53.047085
# 2   742761070  19.5419     NaN     NaN     NaN  111.814226  53.042674
# 3   470987102  18.6348  16.706  15.837  15.919  111.819780  53.047389
# 4   742761069  20.4246     NaN     NaN     NaN  111.793183  53.031054
# ..        ...      ...     ...     ...     ...         ...        ...
# 61  742761089  18.6908     NaN     NaN     NaN  111.881429  53.072788
# 62  742761081  20.3890     NaN     NaN     NaN  111.893627  53.048124
# 63  742820951  19.9516     NaN     NaN     NaN  111.713286  53.028038
# 64  470987086  18.3634  16.536  15.870  15.752  111.749313  52.998533
# 65  742761083  20.2175     NaN     NaN     NaN  111.890331  53.062599
#
#         mass       rad    Teff        plx  sep (arcsec)  PA (E of N)  \
# 0   0.613891  0.632571  3876.0  13.347400         0.000        0.000
# 1   0.870000  0.677439  5135.0   0.986836        12.184       53.810
# 2        NaN       NaN     NaN   0.481227        28.883      107.500
# 3   0.470000  0.425494  3517.0   0.925601        40.422       78.159
# 4        NaN       NaN     NaN  -1.390740        53.630      199.617
# ..       ...       ...     ...        ...           ...          ...
# 61       NaN       NaN  3711.0   0.880022       199.628       59.998
# 62       NaN       NaN     NaN   0.735659       199.682       86.824
# 63       NaN       NaN     NaN        NaN       200.577      252.217
# 64       NaN       NaN  3157.0   2.234230       202.134      214.012
# 65       NaN       NaN     NaN   0.787066       202.291       71.806
#
#        fluxratio    tdepth
# 0   9.770845e-01  0.001548
# 1   1.840914e-02  0.082167
# 2   3.155657e-04  0.000000
# 3   5.323882e-04  0.000000
# 4   1.273282e-05  0.000000
# ..           ...       ...
# 61  3.185287e-26  0.000000
# 62  1.640161e-29  0.000000
# 63  2.886619e-33  0.000000
# 64  3.202100e-33  0.000000
# 65  2.523798e-28  0.000000
#
# [66 rows x 15 columns]

# %%
for i in range (1, np.size(target.stars['ID'])):
    if target.stars['tdepth'][i] !=0:
        print(target.stars['ID'][i])
# Out:
# 470987101
# 470987784

# %% [markdown]
# # Ploting CC File

# %%
cc = pd.read_csv(contrastcurve_file, header=None)
sep, dmag = cc[0].values, cc[1].values

plt.plot(sep, dmag, 'k-');
plt.ylim(9,0);
plt.ylabel("$\\Delta K_s$", fontsize=20);
plt.xlabel("separation ('')", fontsize=20);

# %% [markdown]
# # Calculating FPP & NFPP

# %%
# %%time
# read in the light curve
time, flux, flux_err = lc[0].values, lc[1].values, lc[2].values
P_orb = period

#lc_binsize = (time.max()-time.min())/100
lc = TessLightCurve(time=time, flux=flux, flux_err=flux_err)#.bin(time_bin_size=lc_binsize)

target.calc_probs(time = lc.time.value, 
                  flux_0 = lc.flux.value, 
                  flux_err_0 = np.mean(lc.flux_err.value), 
                  P_orb = P_orb,
                  contrast_curve_file = contrastcurve_file,
                  filt = band,
                  exptime = 0.0013888888888889)
# Out:
# Calculating TP scenario probabilitiey for 470987100.
# Calculating EB and EBx2P scenario probabilities for 470987100.
# Calculating PTP scenario probability for 470987100.
# Calculating PEB and PEBx2P scenario probabilities for 470987100.
# Calculating STP scenario probability for 470987100.
# Calculating SEB and SEBx2P scenario probabilities for 470987100.
# Calculating DTP scenario probability for 470987100.
# Calculating DEB and DEBx2P scenario probabilities for 470987100.
# Calculating BTP scenario probability for 470987100.
# Calculating BEB and BEBx2P scenario probabilities for 470987100.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 470987101.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 470987784.
# Wall time: 40min 53s

# %%
df_results = target.probs
print("FPP = ", target.FPP)
print("NFPP = ", target.NFPP)
df_results
# Out:
# FPP =  0.01728897013446551
# NFPP =  0.015396339456328846
#            ID scenario       M_s       R_s     P_orb        inc         b  \
# 0   470987100       TP  0.613891  0.632571  4.119242  86.258647  0.141077
# 1   470987100       EB  0.613891  0.632571  4.119242  83.353152  1.882610
# 2   470987100    EBx2P  0.613891  0.632571  8.238484  87.698295  0.745067
# 3   470987100      PTP  0.613891  0.632571  4.119242  87.544723  0.273420
# 4   470987100      PEB  0.613891  0.632571  4.119242  85.828901  1.168367
# 5   470987100   PEBx2P  0.613891  0.632571  8.238484  87.479383  0.698181
# 6   470987100      STP  0.604305  0.597670  4.119242  88.999268  0.263966
# 7   470987100      SEB  0.120919  0.148086  4.119242  88.432876  0.095618
# 8   470987100   SEBx2P  0.245657  0.270863  8.238484  88.792892  0.456872
# 9   470987100      DTP  0.613891  0.632571  4.119242  87.153926  0.246247
# 10  470987100      DEB  0.613891  0.632571  4.119242  83.465907  1.775018
# 11  470987100   DEBx2P  0.613891  0.632571  8.238484  87.501669  0.973249
# 12  470987100      BTP  0.875000  0.873047  4.119242  85.916258  0.329202
# 13  470987100      BEB  0.776000  0.704636  4.119242  88.622664  0.362112
# 14  470987100   BEBx2P  0.776000  0.704636  8.238484  86.805515  1.567085
# 15  470987101      NTP  0.870000  0.677439  4.119242  89.602390  0.096861
# 16  470987101      NEB  0.870000  0.677439  4.119242  89.904685  0.027059
# 17  470987101   NEBx2P  0.870000  0.677439  8.238484  87.122896  1.969282
# 18  470987784      NTP  1.070000  1.318200  4.119242  89.980794  0.001491
# 19  470987784      NEB  1.070000  1.318200  4.119242  89.661007  0.036270
# 20  470987784   NEBx2P  1.070000  1.318200  8.238484  89.849121  0.037804
#
#          ecc           w        R_p      M_EB      R_EB          prob
# 0   0.866879  129.376816   2.407601  0.000000  0.000000  8.513792e-01
# 1   0.143872   39.927542   0.000000  0.581281  0.585880  5.434530e-13
# 2   0.636542  186.744692   0.000000  0.588636  0.590504  4.139623e-05
# 3   0.663877  155.706336   3.076965  0.000000  0.000000  2.214921e-02
# 4   0.051387  288.416342   0.000000  0.105902  0.128320  3.118388e-13
# 5   0.771779  200.065892   0.000000  0.589531  0.591016  2.749646e-06
# 6   0.015643  130.632733   3.340841  0.000000  0.000000  1.718910e-04
# 7   0.938576  159.854300   0.000000  0.029710  0.100000  7.037726e-06
# 8   0.735023  175.464509   0.000000  0.242909  0.268443  4.294730e-05
# 9   0.684509  125.547524   2.571758  0.000000  0.000000  1.091826e-01
# 10  0.156263   55.168834   0.000000  0.561195  0.569836  2.795735e-13
# 11  0.490334  181.868685   0.000000  0.597026  0.594824  4.531451e-07
# 12  0.611738   99.264962  14.874483  0.000000  0.000000  2.920652e-05
# 13  0.000020  184.100676   0.000000  0.169901  0.201804  1.061527e-03
# 14  0.005564   22.419211   0.000000  0.772127  0.704636  5.354224e-04
# 15  0.085509   78.530657  19.272120  0.000000  0.000000  4.157345e-04
# 16  0.014857  247.664518   0.000000  0.145704  0.176967  9.974059e-03
# 17  0.292249  268.310863   0.000000  0.850958  0.677439  4.740615e-03
# 18  0.522144  134.594177  19.870807  0.000000  0.000000  3.327128e-17
# 19  0.459171   49.022598   0.000000  1.003532  1.084427  1.605070e-04
# 20  0.593370  335.234792   0.000000  1.020029  1.108458  1.054232e-04

# %%
target.plot_fits(time=time, flux_0=flux, flux_err_0=np.mean(flux_err))
